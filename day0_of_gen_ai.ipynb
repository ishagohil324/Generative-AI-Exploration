# %%
#  Day 0: Introduction to Generative AI


from datetime import date
print(f" Welcome to Day 0 of Generative AI - {date.today()}")

# --- What is Generative AI ---
text = """
Generative AI refers to AI models that can create new data —
such as text, images, music, code, or video —
based on patterns learned from existing data.

These models don’t just analyze information;
they *generate* new content, often indistinguishable from human-made creations.
"""

print(text)

examples = [
    "ChatGPT → text generation",
    "DALL·E → image generation",
    "Suno → music generation",
    "Runway → video generation"
]

print("\n Popular Generative AI Systems:")
for ex in examples:
    print(" -", ex)

print("\n Environment ready! Let's go create cool AI stuff ")
# Out:
#  Welcome to Day 0 of Generative AI - 2025-11-05
#
# Generative AI refers to AI models that can create new data —
# such as text, images, music, code, or video —
# based on patterns learned from existing data.
#
# These models don’t just analyze information;
# they *generate* new content, often indistinguishable from human-made creations.
#
#
#  Popular Generative AI Systems:
#  - ChatGPT → text generation
#  - DALL·E → image generation
#  - Suno → music generation
#  - Runway → video generation
#
#  Environment ready! Let's go create cool AI stuff

# %% [markdown]
# #  Day 0 — Introduction to Generative AI
#
# ###  Goal
# Understand what Generative AI is and set up your environment for the 21-day challenge.
#
# ### Key Learnings
# - Generative AI = models that *create* new data.
# - Core models → **Transformers (text/code)** & **Diffusion Models (images)**.
# - Real-world tools → ChatGPT, DALL·E, Suno, Runway, Claude.
#
# ###  Tools Used
# - Google Colab
# - Python (built-in)
# - OpenAI API (will use later)
#
# ###  Output
# Console messages confirming setup success.
